# %% [markdown]
# # Segment Anything Model for Geospatial Data
#
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeos/segment-geospatial/blob/main/docs/examples/satellite.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/segment-geospatial/blob/main/docs/examples/satellite.ipynb)
#
# This notebook shows how to use segment satellite imagery using the Segment Anything Model (SAM) with a few lines of code.
#
# Make sure you use GPU runtime for this notebook. For Google Colab, go to `Runtime` -> `Change runtime type` and select `GPU` as the hardware accelerator.

# %% [markdown]
# ## Install dependencies
#
# Uncomment and run the following cell to install the required dependencies.

# %%
 pip install segment-geospatial
# Out:
# Requirement already satisfied: segment-geospatial in /usr/local/lib/python3.11/dist-packages (0.12.6)
# Requirement already satisfied: fiona in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.10.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (5.2.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.30.2)
# Requirement already satisfied: ipympl in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.9.7)
# Requirement already satisfied: leafmap in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.43.13)
# Requirement already satisfied: localtileserver in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.10.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (3.10.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (4.11.0.86)
# Requirement already satisfied: patool in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (4.0.1)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (2.0.8)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (3.7.1)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.4.3)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.19.0)
# Requirement already satisfied: sam2 in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.1.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.6.1)
# Requirement already satisfied: segment-anything-hq in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (0.3)
# Requirement already satisfied: segment-anything-py in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.0.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (1.0.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (4.67.1)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (2025.3.1)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from segment-geospatial) (2025.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.11/dist-packages (from fiona->segment-geospatial) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from fiona->segment-geospatial) (2025.4.26)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.11/dist-packages (from fiona->segment-geospatial) (8.1.8)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.11/dist-packages (from fiona->segment-geospatial) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.11/dist-packages (from fiona->segment-geospatial) (0.7.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->segment-geospatial) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown->segment-geospatial) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown->segment-geospatial) (2.32.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas->segment-geospatial) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas->segment-geospatial) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas->segment-geospatial) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->segment-geospatial) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas->segment-geospatial) (2.1.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->segment-geospatial) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->segment-geospatial) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->segment-geospatial) (4.13.2)
# Requirement already satisfied: ipython<10 in /usr/local/lib/python3.11/dist-packages (from ipympl->segment-geospatial) (7.34.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.11/dist-packages (from ipympl->segment-geospatial) (7.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from ipympl->segment-geospatial) (11.2.1)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.11/dist-packages (from ipympl->segment-geospatial) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->segment-geospatial) (2.9.0.post0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.9.18)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.12.44)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.1.5)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (1.2.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.19.5)
# Requirement already satisfied: geojson in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (3.2.0)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (2.0.2)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.19.2)
# Requirement already satisfied: ipyvuetify in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (1.11.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (5.24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (5.9.5)
# Requirement already satisfied: pyshp in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (2.3.1)
# Requirement already satisfied: pystac-client in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.8.6)
# Requirement already satisfied: python-box in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (0.10.1)
# Requirement already satisfied: whiteboxgui in /usr/local/lib/python3.11/dist-packages (from leafmap->segment-geospatial) (2.3.0)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (3.1.0)
# Requirement already satisfied: Flask-Caching in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (2.3.1)
# Requirement already satisfied: flask-cors in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (5.0.1)
# Requirement already satisfied: flask-restx>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (1.3.0)
# Requirement already satisfied: rio-tiler in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (7.7.0)
# Requirement already satisfied: rio-cogeo in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (5.4.1)
# Requirement already satisfied: server-thread in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (0.3.0)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.11/dist-packages (from localtileserver->segment-geospatial) (3.1.3)
# Requirement already satisfied: affine in /usr/local/lib/python3.11/dist-packages (from rasterio->segment-geospatial) (2.4.0)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from sam2->segment-geospatial) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from sam2->segment-geospatial) (0.21.0+cu124)
# Requirement already satisfied: hydra-core>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from sam2->segment-geospatial) (1.3.2)
# Requirement already satisfied: iopath>=0.1.10 in /usr/local/lib/python3.11/dist-packages (from sam2->segment-geospatial) (0.1.10)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->segment-geospatial) (1.15.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->segment-geospatial) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->segment-geospatial) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->segment-geospatial) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->segment-geospatial) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->segment-geospatial) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->segment-geospatial) (3.6.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->segment-geospatial) (0.5.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask<4,>=2.0.0->localtileserver->segment-geospatial) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (10.0.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (4.23.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (2025.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from flask-restx>=1.3.0->localtileserver->segment-geospatial) (6.5.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.3.2->sam2->segment-geospatial) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.3.2->sam2->segment-geospatial) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.10->sam2->segment-geospatial) (3.1.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<10->ipympl->segment-geospatial) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (3.0.14)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas->segment-geospatial) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->segment-geospatial) (1.17.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->sam2->segment-geospatial) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5.1->sam2->segment-geospatial) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug->localtileserver->segment-geospatial) (3.0.2)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from anywidget->leafmap->segment-geospatial) (0.13.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.7)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.11/dist-packages (from bqplot->leafmap->segment-geospatial) (0.2.1)
# Requirement already satisfied: cachelib>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask-Caching->localtileserver->segment-geospatial) (0.13.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium->leafmap->segment-geospatial) (0.8.1)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet->leafmap->segment-geospatial) (0.19.2)
# Requirement already satisfied: ipyvue<2,>=1.7 in /usr/local/lib/python3.11/dist-packages (from ipyvuetify->leafmap->segment-geospatial) (1.11.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->leafmap->segment-geospatial) (9.1.2)
# Requirement already satisfied: pystac>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap->segment-geospatial) (1.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->segment-geospatial) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->segment-geospatial) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->segment-geospatial) (2.4.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from rio-cogeo->localtileserver->segment-geospatial) (6.2.0)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.11/dist-packages (from rio-cogeo->localtileserver->segment-geospatial) (2.11.4)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (5.5.2)
# Requirement already satisfied: color-operations in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (0.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from rio-tiler->localtileserver->segment-geospatial) (2.10.2)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (from server-thread->localtileserver->segment-geospatial) (0.34.2)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.11/dist-packages (from whiteboxgui->leafmap->segment-geospatial) (0.2.2)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.11/dist-packages (from whiteboxgui->leafmap->segment-geospatial) (2.3.6)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (6.1.12)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (6.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<10->ipympl->segment-geospatial) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<10->ipympl->segment-geospatial) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<10->ipympl->segment-geospatial) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver->segment-geospatial) (0.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->segment-geospatial) (0.24.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (6.5.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->rio-tiler->localtileserver->segment-geospatial) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver->segment-geospatial) (0.16.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (5.7.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->rio-tiler->localtileserver->segment-geospatial) (1.3.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (2.21.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl->segment-geospatial) (1.8.0)

# %% [markdown]
# ## Import libraries

# %%
import os
import leafmap
from samgeo import SamGeo, tms_to_geotiff, get_basemaps

# %% [markdown]
# ## Create an interactive map

# %%
m = leafmap.Map(center=[37.8713, -122.2580], zoom=19)
#m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[37.8713, -122.258], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Pan and zoom the map to select the area of interest. Use the draw tools to draw a polygon or rectangle on the map

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [-95.3704, 29.6762, -95.368, 29.6775]

# %%
m.user_roi_bounds()
# Out:
# [-122.267, 37.8685, -122.2524, 37.875]

# %% [markdown]
# ## Download map tiles
#
# Download maps tiles and mosaic them into a single GeoTIFF file

# %%
image = "satellite.tif"

# %% [markdown]
# Besides the `satellite` basemap, you can use any of the following basemaps returned by the `get_basemaps()` function:

# %%
# get_basemaps().keys()
# Out:
# dict_keys(['BaseMapDE.Color', 'BaseMapDE.Grey', 'BasemapAT.basemap', 'BasemapAT.grau', 'BasemapAT.highdpi', 'BasemapAT.orthofoto', 'BasemapAT.overlay', 'BasemapAT.surface', 'BasemapAT.terrain', 'CartoDB.DarkMatter', 'CartoDB.DarkMatterNoLabels', 'CartoDB.DarkMatterOnlyLabels', 'CartoDB.Positron', 'CartoDB.PositronNoLabels', 'CartoDB.PositronOnlyLabels', 'CartoDB.Voyager', 'CartoDB.VoyagerLabelsUnder', 'CartoDB.VoyagerNoLabels', 'CartoDB.VoyagerOnlyLabels', 'CyclOSM', 'Esri.AntarcticBasemap', 'Esri.AntarcticImagery', 'Esri.ArcticImagery', 'Esri.ArcticOceanBase', 'Esri.ArcticOceanReference', 'Esri.NatGeoWorldMap', 'Esri.OceanBasemap', 'Esri.WorldGrayCanvas', 'Esri.WorldImagery', 'Esri.WorldPhysical', 'Esri.WorldShadedRelief', 'Esri.WorldStreetMap', 'Esri.WorldTerrain', 'Esri.WorldTopoMap', 'FreeMapSK', 'Gaode.Normal', 'Gaode.Satellite', 'GeoportailFrance.500k', 'GeoportailFrance.Acces_Biomethane', 'GeoportailFrance.Adminexpress_cog_2017', 'GeoportailFrance.Adminexpress_cog_2018', 'GeoportailFrance.Adminexpress_cog_2019', 'GeoportailFrance.Adminexpress_cog_2020', 'GeoportailFrance.Adminexpress_cog_2021', 'GeoportailFrance.Adminexpress_cog_2022', 'GeoportailFrance.Adminexpress_cog_2023', 'GeoportailFrance.Adminexpress_cog_2024', 'GeoportailFrance.Adminexpress_cog_2025', 'GeoportailFrance.Adminexpress_cog_Latest', 'GeoportailFrance.Adminexpress_cog_carto_Latest', 'GeoportailFrance.Aire-parcellaire', 'GeoportailFrance.Areamanagement_Zfu', 'GeoportailFrance.Areamanagement_Zus', 'GeoportailFrance.Bdcarto_etat_major_Niveau3', 'GeoportailFrance.Bdcarto_etat_major_Niveau4', 'GeoportailFrance.Besoin_Chaleur_Industriel', 'GeoportailFrance.Besoin_Chaleur_Residentiel', 'GeoportailFrance.Besoin_Chaleur_Tertiaire', 'GeoportailFrance.Besoin_Froid_Residentiel', 'GeoportailFrance.Besoin_Froid_Tertiaire', 'GeoportailFrance.Bnf_ignf_geographicalgridsystems_Cassini', 'GeoportailFrance.Buildings_Buildings', 'GeoportailFrance.Cadastral_Parcels_Sections', 'GeoportailFrance.Cadastralparcels_Heatmap', 'GeoportailFrance.Cadastralparcels_Histo_2008_2013_Parcels', 'GeoportailFrance.Cadastralparcels_Parcellaire_express_L93', 'GeoportailFrance.Cadastralparcels_Parcels', 'GeoportailFrance.Cadastralparcels_Parcels_L93', 'GeoportailFrance.Cadastralparcels_Qualrefbdp', 'GeoportailFrance.Cadastres_Solaires_Locaux', 'GeoportailFrance.Capacite_Accueil_Electrique', 'GeoportailFrance.Carhab_habitat', 'GeoportailFrance.Cartes-14-18-edugeo_pyr-png_fxx_wm', 'GeoportailFrance.Cartes_Naturalearth', 'GeoportailFrance.Cget_qp_bdd_wld_wm_wmts_20150914', 'GeoportailFrance.Communes_Prioritydisctrict', 'GeoportailFrance.Communes_Sismicite', 'GeoportailFrance.Conso_Elec_Commune', 'GeoportailFrance.Conso_Gaz_Commune', 'GeoportailFrance.Cosia', 'GeoportailFrance.Debroussaillement', 'GeoportailFrance.Delaisses_Autoroutiers', 'GeoportailFrance.Dreal_Zonage_pinel', 'GeoportailFrance.Edugeo_Landuse_Agriculture2012', 'GeoportailFrance.Edugeo_Naturalriskzones_1910floodedwatersheds', 'GeoportailFrance.Elevation_Contour_Line', 'GeoportailFrance.Elevation_Elevationgridcoverage_Shadow', 'GeoportailFrance.Elevation_Elevationgridcoverage_Threshold', 'GeoportailFrance.Elevation_Level0', 'GeoportailFrance.Elevation_Slopes', 'GeoportailFrance.Elevation_Slopes_Highres', 'GeoportailFrance.Elevationgridcoverage_Highres_Quality', 'GeoportailFrance.Enr_Aero_Civil', 'GeoportailFrance.Enr_Aero_Militaire', 'GeoportailFrance.Enr_Grands_Sites_France', 'GeoportailFrance.Enr_Perimetre_Habitation', 'GeoportailFrance.Enr_Perimetre_Pente', 'GeoportailFrance.Enr_Perimetre_Route', 'GeoportailFrance.Enr_Perimetre_Voie_Ferree', 'GeoportailFrance.Enrezo_Besoins_Chaud', 'GeoportailFrance.Enrezo_Besoins_Froid', 'GeoportailFrance.Enrezo_Chaleur_Fatale_500_Industries', 'GeoportailFrance.Enrezo_Chaleur_Fatale_Datacenter', 'GeoportailFrance.Enrezo_Chaleur_Fatale_Step', 'GeoportailFrance.Enrezo_Zone_Potentiel_Chaud', 'GeoportailFrance.Enrezo_Zone_Potentiel_Fort_Chaud', 'GeoportailFrance.Enrezo_Zone_Potentiel_Fort_Froid', ' ...

# %% [markdown]
# Specify the basemap as the source.

# %%
tms_to_geotiff(output=image, bbox=bbox, zoom=20, source="Satellite", overwrite=True)
# Out:
# Downloaded image 0001/1100
# Downloaded image 0002/1100
# Downloaded image 0003/1100
# Downloaded image 0004/1100
# Downloaded image 0005/1100
# Downloaded image 0006/1100
# Downloaded image 0007/1100
# Downloaded image 0008/1100
# Downloaded image 0009/1100
# Downloaded image 0010/1100
# Downloaded image 0011/1100
# Downloaded image 0012/1100
# Downloaded image 0013/1100
# Downloaded image 0014/1100
# Downloaded image 0015/1100
# Downloaded image 0016/1100
# Downloaded image 0017/1100
# Downloaded image 0018/1100
# Downloaded image 0019/1100
# Downloaded image 0020/1100
# Downloaded image 0021/1100
# Downloaded image 0022/1100
# Downloaded image 0023/1100
# Downloaded image 0024/1100
# Downloaded image 0025/1100
# Downloaded image 0026/1100
# Downloaded image 0027/1100
# Downloaded image 0028/1100
# Downloaded image 0029/1100
# Downloaded image 0030/1100
# Downloaded image 0031/1100
# Downloaded image 0032/1100
# Downloaded image 0033/1100
# Downloaded image 0034/1100
# Downloaded image 0035/1100
# Downloaded image 0036/1100
# Downloaded image 0037/1100
# Downloaded image 0038/1100
# Downloaded image 0039/1100
# Downloaded image 0040/1100
# Downloaded image 0041/1100
# Downloaded image 0042/1100
# Downloaded image 0043/1100
# Downloaded image 0044/1100
# Downloaded image 0045/1100
# Downloaded image 0046/1100
# Downloaded image 0047/1100
# Downloaded image 0048/1100
# Downloaded image 0049/1100
# Downloaded image 0050/1100
# Downloaded image 0051/1100
# Downloaded image 0052/1100
# Downloaded image 0053/1100
# Downloaded image 0054/1100
# Downloaded image 0055/1100
# Downloaded image 0056/1100
# Downloaded image 0057/1100
# Downloaded image 0058/1100
# Downloaded image 0059/1100
# Downloaded image 0060/1100
# Downloaded image 0061/1100
# Downloaded image 0062/1100
# Downloaded image 0063/1100
# Downloaded image 0064/1100
# Downloaded image 0065/1100
# Downloaded image 0066/1100
# Downloaded image 0067/1100
# Downloaded image 0068/1100
# Downloaded image 0069/1100
# Downloaded image 0070/1100
# Downloaded image 0071/1100
# Downloaded image 0072/1100
# Downloaded image 0073/1100
# Downloaded image 0074/1100
# Downloaded image 0075/1100
# Downloaded image 0076/1100
# Downloaded image 0077/1100
# Downloaded image 0078/1100
# Downloaded image 0079/1100
# Downloaded image 0080/1100
# Downloaded image 0081/1100
# Downloaded image 0082/1100
# Downloaded image 0083/1100
# Downloaded image 0084/1100
# Downloaded image 0085/1100
# Downloaded image 0086/1100
# Downloaded image 0087/1100
# Downloaded image 0088/1100
# Downloaded image 0089/1100
# Downloaded image 0090/1100
# Downloaded image 0091/1100
# Downloaded image 0092/1100
# Downloaded image 0093/1100
# Downloaded image 0094/1100
# Downloaded image 0095/1100
# Downloaded image 0096/1100
# Downloaded image 0097/1100
# Downloaded image 0098/1100
# Downloaded image 0099/1100
# Downloaded image 0100/1100
# Downloaded image 0101/1100
# Downloaded image 0102/1100
# Downloaded image 0103/1100
# Downloaded image 0104/1100
# Downloaded image 0105/1100
# Downloaded image 0106/1100
# Downloaded image 0107/1100
# Downloaded image 0108/1100
# Downloaded image 0109/1100
# Downloaded image 0110/1100
# Downloaded image 0111/1100
# Downloaded image 0112/1100
# Downloaded image 0113/1100
# Downloaded image 0114/1100
# Downloaded image 0115/1100
# Downloaded image 0116/1100
# Downloaded image 0117/1100
# Downloaded image 0118/1100
# Downloaded image 0119/1100
# Downloaded image 0120/1100
# Downloaded image 0121/1100
# Downloaded image 0122/1100
# Downloaded image 0123/1100
# Downloaded image 0124/1100
# Downloaded image 0125/1100
# Downloaded image 0126/1100
# Downloaded image 0127/1100
# Downloaded image 0128/1100
# Downloaded image 0129/1100
# Downloaded image 0130/1100
# Downloaded image 0131/1100
# Downloaded image 0132/1100
# Downloaded image 0133/1100
# Downloaded image 0134/1100
# Downloaded image 0135/1100
# Downloaded image 0136/1100
# Downloaded image 0137/1100
# Downloaded image 0138/1100
# Downloaded image 0139/1100
# Downloaded image 0140/1100
# Downloaded image 0141/1100
# Downloaded image 0142/1100
# Downloaded image 0143/1100
# Downloaded image 0144/1100
# Downloaded image 0145/1100
# Downloaded image 0146/1100
# Downloaded image 0147/1100
# Downloaded image 0148/1100
# Downloaded image 0149/1100
# Downloaded image 0150/1100
# Downloaded image 0151/1100
# Downloaded image 0152/1100
# Downloaded image 0153/1100
# Downloaded image 0154/1100
# Downloaded image 0155/1100
# Downloaded image 0156/1100
# Downloaded image 0157/1100
# Downloaded image 0158/1100
# Downloaded image 0159/1100
# Downloaded image 0160/1100
# Downloaded image 0161/1100
# Downloaded image 0162/1100
# Downloaded image 0163/1100
# Downloaded image 0164/1100
# Downloaded image 0165/1100
# Downloaded image 0166/1100
# Downloaded image 0167/1100
# Downloaded image 0168/1100
# Downloaded image 0169/1100
# Downloaded image 0170/1100
# Downloaded image 0171/1100
# Downloaded image 0172/1100
# Downloaded image 0173/1100
# Downloaded image 0174/1100
# Downloaded image 0175/1100
# Downloaded image 0176/1100
# Downloaded image 0177/1100
# Downloaded image 0178/1100
# Downloaded image 0179/1100
# Downloaded image 0180/1100
# Downloaded image 0181/1100
# Downloaded image 0182/1100
# Downloaded image 0183/1100
# Downloaded image 0184/1100
# Downloaded image 0185/1100
# Downloaded image 0186/1100
# Downloaded image 0187/1100
# Downloaded image 0188/1100
# Downloaded image 0189/1100
# Downloaded image 0190/1100
# Downloaded image 0191/1100
# Downloaded image 0192/1100
# Downloaded image 0193/1100
# Downloaded image 0194/1100
# Downloaded image 0195/1100
# Downloaded image 0196/1100
# Downloaded image 0197/1100
# Downloaded image 0198/1100
# Downloaded image 0199/1100
# Downloaded image 0200/1100
# Downloaded image 0201/1100
# Downloaded image 0202/1100
# Downloaded image 0203/1100
# Downloaded image 0204/1100
# Downloaded image 0205/1100
# Downloaded image 0206/1100
# Downloaded image 0207/1100
# Downloaded image 0208/1100
# Downloaded image 0209/1100
# Downloaded image 0210/1100
# Downloaded image 0211/1100
# Downloaded image 0212/1100
# Downloaded image 0213/1100
# Downloaded image 0214/1100
# Downloaded image 0215/1100
# Downloaded image 0216/1100
# Downloaded image 0217/1100
# Downloaded image 0218/1100
# Downloaded image 0219/1100
# Downloaded image 0220/1100
# Downloaded image 0221/1100
# Downloaded image 0222/1100
# Downloaded image 0223/1100
# Downloaded image 0224/1100
# Downloaded image 0225/1100
# Downloaded image 0226/1100
# Downloaded image 0227/1100
# Downloaded image 0228/1100
# Downloaded image 0229/1100
# Downloaded image 0230/1100
# Downloaded image 0231/1100
# Downloaded image 0232/1100
# Downloaded image 0233/1100
# Downloaded image 0234/1100
# Downloaded image 0235/1100
# Downloaded image 0236/1100
# Downloaded image 0237/1100
# Downloaded image 0238/1100
# Downloaded image 0239/1100
# Downloaded image 0240/1100
# Downloaded image 0241/1100
# Downloaded image 0242/1100
# Downloaded image 0243/1100
# Downloaded image 0244/1100
# Downloaded image 0245/1100
# Downloaded image 0246/1100
# Downloaded image 0247/1100
# Downloaded image 0248/1100
# Downloaded image 0249/1100
# Downloaded image 0250/1100
# Downloaded image 0251/1100
# Downloaded image 0252/1100
# Downloaded image 0253/1100
# Downloaded image 0254/1100
# Downloaded image 0255/1100
# Downloaded image 0256/1100
# Downloaded image 0257/1100
# Downloaded image 0258/1100
# Downloaded image 0259/1100
# Downloaded image 0260/1100
# Downloaded image 0261/1100
# Downloaded image 0262/1100
# Downloaded image 0263/1100
# Downloaded image 0264/1100
# Downloaded image 0265/1100
# Downloaded image 0266/1100
# Downloaded image 0267/1100
# Downloaded image 0268/1100
# Downloaded image 0269/1100
# Downloaded image 0270/1100
# Downloaded image 0271/1100
# Downloaded image 0272/1100
# Downloaded image 0273/1100
# Downloaded image 0274/1100
# Downloaded image 0275/1100
# Downloaded image 0276/1100
# Downloaded image 0277/1100
# Downloaded image 0278/1100
# Downloaded image 0279/1100
# Downloaded image 0280/1100
# Downloaded image 0281/1100
# Downloaded image 0282/1100
# Downloaded image 0283/1100
# Downloaded image 0284/1100
# Downloaded image 0285/1100
# Downloaded image 0286/1100
# Downloaded image 0287/1100
# Downloaded image 0288/1100
# Downloaded image 0289/1100
# Downloaded image 0290/1100
# Downloaded image 0291/1100
# Downloaded image 0292/1100
# Downloaded image 0293/1100
# Downloaded image 0294/1100
# Downloaded image 0295/1100
# Downloaded image 0296/1100
# Downloaded image 0297/1100
# Downloaded image 0298/1100
# Downloaded image 0299/1100
# Downloaded image 0300/1100
# Downloaded image 0301/1100
# Downloaded image 0302/1100
# Downloaded image 0303/1100
# Downloaded image 0304/1100
# Downloaded image 0305/1100
# Downloaded image 0306/1100
# Downloaded image 0307/1100
# Downloaded image 0308/1100
# Downloaded image 0309/1100
# Downloaded image 0310/1100
# Downloaded image 0311/1100
# Downloaded image 0312/1100
# Downloaded image 0313/1100
# Downloaded image 0314/1100
# Downloaded image 0315/1100
# Downloaded image 0316/1100
# Downloaded image 0317/1100
# Downloaded image 0318/1100
# Downloaded image 0319/1100
# Downloaded image 0320/1100
# Downloaded image 0321/1100
# Downloaded image 0322/1100
# Downloaded image 0323/1100
# Downloaded image 0324/1100
# Downloaded image 0325/1100
# Downloaded image 0326/1100
# Downloaded image 0327/1100
# Downloaded image 0328/1100
# Downloaded image 0329/1100
# Downloaded image 0330/1100
# Downloaded image 0331/1100
# Downloaded image 0332/1100
# Downloaded image 0333/1100
# Downloaded image 0334/1100
# Downloaded image 0335/1100
# Downloaded image 0336/1100
# Downloaded image 0337/1100
# Downloaded image 0338/1100
# Downloaded image 0339/1100
# Downloaded image 0340/1100
# Downloaded image 0341/1100
# Downloaded image 0342/1100
# Downloaded image 0343/1100
# Downloaded image 0344/1100
# Downloaded image 0345/1100
# Downloaded image 0346/1100
# Downloaded image 0347/1100
# Downloaded image 0348/1100
# Downloaded image 0349/1100
# Downloaded image 0350/1100
# Downloaded image 0351/1100
# Downloaded image 0352/1100
# Downloaded image 0353/1100
# Downloaded image 0354/1100
# Downloaded image 0355/1100
# Downloaded image 0356/1100
# Downloaded image 0357/1100
# Downloaded image 0358/1100
# Downloaded image 0359/1100
# Downloaded image 0360/1100
# Downloaded image 0361/1100
# Downloaded image 0362/1100
# Downloaded image 0363/1100
# Downloaded image 0364/1100
# Downloaded image 0365/1100
# Downloaded image 0366/1100
# Downloaded image 0367/1100
# Downloaded image 0368/1100
# Downloaded image 0369/1100
# Downloaded image 0370/1100
# Downloaded image 0371/1100
# Downloaded image 0372/1100
# Downloaded image 0373/1100
# Downloaded image 0374/1100
# Downloaded image 0375/1100
# Downloaded image 0376/1100
# Downloaded image 0377/1100
# Downloaded image 0378/1100
# Downloaded image 0379/1100
# Downloaded image 0380/1100
# Downloaded image 0381/1100
# Downloaded image 0382/1100
# Downloaded image 0383/1100
# Downloaded image 0384/1100
# Downloaded image 0385/1100
# Downloaded image 0386/1100
# Downloaded image 0387/1100
# Downloaded image 0388/1100
# Downloaded image 0389/1100
# Downloaded image 0390/1100
# Downloaded image 0391/1100
# Downloaded image 0392/1100
# Downloaded image 0393/1100
# Downloaded image 0394/1100
# Downloaded image 0395/1100
# Downloaded image 0396/1100
# Downloaded image 0397/1100
# Downloaded image 0398/1100
# Downloaded image 0399/1100
# Downloaded image 0400/1100
# Downloaded image 0401/1100
# Downloaded image 0402/1100
# Downloaded image 0403/1100
# Downloaded image 0404/1100
# Downloaded image 0405/1100
# Downloaded image 0406/1100
# Downloaded image 0407/1100
# Downloaded image 0408/1100
# Downloaded image 0409/1100
# Downloaded image 0410/1100
# Downloaded image 0411/1100
# Downloaded image 0412/1100
# Downloaded image 0413/1100
# Downloaded image 0414/1100
# Downloaded image 0415/1100
# Downloaded image 0416/1100
# Downloaded image 0417/1100
# Downloaded image 0418/1100
# Downloaded image 0419/1100
# Downloaded image 0420/1100
# Downloaded image 0421/1100
# Downloaded image 0422/1100
# Downloaded image 0423/1100
# Downloaded image 0424/1100
# Downloaded image 0425/1100
# Downloaded image 0426/1100
# Downloaded image 0427/1100
# Downloaded image 0428/1100
# Downloaded image 0429/1100
# Downloaded image 0430/1100
# Downloaded image 0431/1100
# Downloaded image 0432/1100
# Downloaded image 0433/1100
# Downloaded image 0434/1100
# Downloaded image 0435/1100
# Downloaded image 0436/1100
# Downloaded image 0437/1100
# Downloaded image 0438/1100
# Downloaded image 0439/1100
# Downloaded image 0440/1100
# Downloaded image 0441/1100
# Downloaded image 0442/1100
# Downloaded image 0443/1100
# Downloaded image 0444/1100
# Downloaded image 0445/1100
# Downloaded image 0446/1100
# Downloaded image 0447/1100
# Downloaded image 0448/1100
# Downloaded image 0449/1100
# Downloaded image 0450/1100
# Downloaded image 0451/1100
# Downloaded image 0452/1100
# Downloaded image 0453/1100
# Downloaded image 0454/1100
# Downloaded image 0455/1100
# Downloaded image 0456/1100
# Downloaded image 0457/1100
# Downloaded image 0458/1100
# Downloaded image 0459/1100
# Downloaded image 0460/1100
# Downloaded image 0461/1100
# Downloaded image 0462/1100
# Downloaded image 0463/1100
# Downloaded image 0464/1100
# Downloaded image 0465/1100
# Downloaded image 0466/1100
# Downloaded image 0467/1100
# Downloaded image 0468/1100
# Downloaded image 0469/1100
# Downloaded image 0470/1100
# Downloaded image 0471/1100
# Downloaded image 0472/1100
# Downloaded image 0473/1100
# Downloaded image 0474/1100
# Downloaded image 0475/1100
# Downloaded image 0476/1100
# Downloaded image 0477/1100
# Downloaded image 0478/1100
# Downloaded image 0479/1100
# Downloaded image 0480/1100
# Downloaded image 0481/1100
# Downloaded image 0482/1100
# Downloaded image 0483/1100
# Downloaded image 0484/1100
# Downloaded image 0485/1100
# Downloaded image 0486/1100
# Downloaded image 0487/1100
# Downloaded image 0488/1100
# Downloaded image 0489/1100
# Downloaded image 0490/1100
# Downloaded image 0491/1100
# Downloaded image 0492/1100
# Downloaded image 0493/1100
# Downloaded image 0494/1100
# Downloaded image 0495/1100
# Downloaded image 0496/1100
# Downloaded image 0497/1100
# Downloaded image 0498/1100
# Downloaded image 0499/1100
# Downloaded image 0500/1100
# Downloaded image 0501/1100
# Downloaded image 0502/1100
# Downloaded image 0503/1100
# Downloaded image 0504/1100
# Downloaded image 0505/1100
# Downloaded image 0506/1100
# Downloaded image 0507/1100
# Downloaded image 0508/1100
# Downloaded image 0509/1100
# Downloaded image 0510/1100
# Downloaded image 0511/1100
# Downloaded image 0512/1100
# Downloaded image 0513/1100
# Downloaded image 0514/1100
# Downloaded image 0515/1100
# Downloaded image 0516/1100
# Downloaded image 0517/1100
# Downloaded image 0518/1100
# Downloaded image 0519/1100
# Downloaded image 0520/1100
# Downloaded image 0521/1100
# Downloaded image 0522/1100
# Downloaded image 0523/1100
# Downloaded image 0524/1100
# Downloaded image 0525/1100
# Downloaded image 0526/1100
# Downloaded image 0527/1100
# Downloaded image 0528/1100
# Downloaded image 0529/1100
# Downloaded image 0530/1100
# Downloaded image 0531/1100
# Downloaded image 0532/1100
# Downloaded image 0533/1100
# Downloaded image 0534/1100
# Downloaded image 0535/1100
# Downloaded image 0536/1100
# Downloaded image 0537/1100
# Downloaded image 0538/1100
# Downloaded image 0539/1100
# Downloaded image 0540/1100
# Downloaded image 0541/1100
# Downloaded image 0542/1100
# Downloaded image 0543/1100
# Downloaded image 0544/1100
# Downloaded image 0545/1100
# Downloaded image 0546/1100
# Downloaded image 0547/1100
# Downloaded image 0548/1100
# Downloaded image 0549/1100
# Downloaded image 0550/1100
# Downloaded image 0551/1100
# Downloaded image 0552/1100
# Downloaded image 0553/1100
# Downloaded image 0554/1100
# Downloaded image 0555/1100
# Downloaded image 0556/1100
# Downloaded image 0557/1100
# Downloaded image 0558/1100
# Downloaded image 0559/1100
# Downloaded image 0560/1100
# Downloaded image 0561/1100
# Downloaded image 0562/1100
# Downloaded image 0563/1100
# Downloaded image 0564/1100
# Downloaded image 0565/1100
# Downloaded image 0566/1100
# Downloaded image 0567/1100
# Downloaded image 0568/1100
# Downloaded image 0569/1100
# Downloaded image 0570/1100
# Downloaded image 0571/1100
# Downloaded image 0572/1100
# Downloaded image 0573/1100
# Downloaded image 0574/1100
# Downloaded image 0575/1100
# Downloaded image 0576/1100
# Downloaded image 0577/1100
# Downloaded image 0578/1100
# Downloaded image 0579/1100
# Downloaded image 0580/1100
# Downloaded image 0581/1100
# Downloaded image 0582/1100
# Downloaded image 0583/1100
# Downloaded image 0584/1100
# Downloaded image 0585/1100
# Downloaded image 0586/1100
# Downloaded image 0587/1100
# Downloaded image 0588/1100
# Downloaded image 0589/1100
# Downloaded image 0590/1100
# Downloaded image 0591/1100
# Downloaded image 0592/1100
# Downloaded image 0593/1100
# Downloaded image 0594/1100
# Downloaded image 0595/1100
# Downloaded image 0596/1100
# Downloaded image 0597/1100
# Downloaded image 0598/1100
# Downloaded image 0599/1100
# Downloaded image 0600/1100
# Downloaded image 0601/1100
# Downloaded image 0602/1100
# Downloaded image 0603/1100
# Downloaded image 0604/1100
# Downloaded image 0605/1100
# Downloaded image 0606/1100
# Downloaded image 0607/1100
# Downloaded image 0608/1100
# Downloaded image 0609/1100
# Downloaded image 0610/1100
# Downloaded image 0611/1100
# Downloaded image 0612/1100
# Downloaded image 0613/1100
# Downloaded image 0614/1100
# Downloaded image 0615/1100
# Downloaded image 0616/1100
# Downloaded image 0617/1100
# Downloaded image 0618/1100
# Downloaded image 0619/1100
# Downloaded image 0620/1100
# Downloaded image 0621/1100
# Downloaded image 0622/1100
# Downloaded image 0623/1100
# Downloaded image 0624/1100
# Downloaded image 0625/1100
# Downloaded image 0626/1100
# Downloaded image 0627/1100
# Downloaded image 0628/1100
# Downloaded image 0629/1100
# Downloaded image 0630/1100
# Downloaded image 0631/1100
# Downloaded image 0632/1100
# Downloaded image 0633/1100
# Downloaded image 0634/1100
# Downloaded image 0635/1100
# Downloaded image 0636/1100
# Downloaded image 0637/1100
# Downloaded image 0638/1100
# Downloaded image 0639/1100
# Downloaded image 0640/1100
# Downloaded image 0641/1100
# Downloaded image 0642/1100
# Downloaded image 0643/1100
# Downloaded image 0644/1100
# Downloaded image 0645/1100
# Downloaded image 0646/1100
# Downloaded image 0647/1100
# Downloaded image 0648/1100
# Downloaded image 0649/1100
# Downloaded image 0650/1100
# Downloaded image 0651/1100
# Downloaded image 0652/1100
# Downloaded image 0653/1100
# Downloaded image 0654/1100
# Downloaded image 0655/1100
# Downloaded image 0656/1100
# Downloaded image 0657/1100
# Downloaded image 0658/1100
# Downloaded image 0659/1100
# Downloaded image 0660/1100
# Downloaded image 0661/1100
# Downloaded image 0662/1100
# Downloaded image 0663/1100
# Downloaded image 0664/1100
# Downloaded image 0665/1100
# Downloaded image 0666/1100
# Downloaded image 0667/1100
# Downloaded image 0668/1100
# Downloaded image 0669/1100
# Downloaded image 0670/1100
# Downloaded image 0671/1100
# Downloaded image 0672/1100
# Downloaded image 0673/1100
# Downloaded image 0674/1100
# Downloaded image 0675/1100
# Downloaded image 0676/1100
# Downloaded image 0677/1100
# Downloaded image 0678/1100
# Downloaded image 0679/1100
# Downloaded image 0680/1100
# Downloaded image 0681/1100
# Downloaded image 0682/1100
# Downloaded image 0683/1100
# Downloaded image 0684/1100
# Downloaded image 0685/1100
# Downloaded image 0686/1100
# Downloaded image 0687/1100
# Downloaded image 0688/1100
# Downloaded image 0689/1100
# Downloaded image 0690/1100
# Downloaded image 0691/1100
# Downloaded image 0692/1100
# Downloaded image 0693/1100
# Downloaded image 0694/1100
# Downloaded image 0695/1100
# Downloaded image 0696/1100
# Downloaded image 0697/1100
# Downloaded image 0698/1100
# Downloaded image 0699/1100
# Downloaded image 0700/1100
# Downloaded image 0701/1100
# Downloaded image 0702/1100
# Downloaded image 0703/1100
# Downloaded image 0704/1100
# Downloaded image 0705/1100
# Downloaded image 0706/1100
# Downloaded image 0707/1100
# Downloaded image 0708/1100
# Downloaded image 0709/1100
# Downloaded image 0710/1100
# Downloaded image 0711/1100
# Downloaded image 0712/1100
# Downloaded image 0713/1100
# Downloaded image 0714/1100
# Downloaded image 0715/1100
# Downloaded image 0716/1100
# Downloaded image 0717/1100
# Downloaded image 0718/1100
# Downloaded image 0719/1100
# Downloaded image 0720/1100
# Downloaded image 0721/1100
# Downloaded image 0722/1100
# Downloaded image 0723/1100
# Downloaded image 0724/1100
# Downloaded image 0725/1100
# Downloaded image 0726/1100
# Downloaded image 0727/1100
# Downloaded image 0728/1100
# Downloaded image 0729/1100
# Downloaded image 0730/1100
# Downloaded image 0731/1100
# Downloaded image 0732/1100
# Downloaded image 0733/1100
# Downloaded image 0734/1100
# Downloaded image 0735/1100
# Downloaded image 0736/1100
# Downloaded image 0737/1100
# Downloaded image 0738/1100
# Downloaded image 0739/1100
# Downloaded image 0740/1100
# Downloaded image 0741/1100
# Downloaded image 0742/1100
# Downloaded image 0743/1100
# Downloaded image 0744/1100
# Downloaded image 0745/1100
# Downloaded image 0746/1100
# Downloaded image 0747/1100
# Downloaded image 0748/1100
# Downloaded image 0749/1100
# Downloaded image 0750/1100
# Downloaded image 0751/1100
# Downloaded image 0752/1100
# Downloaded image 0753/1100
# Downloaded image 0754/1100
# Downloaded image 0755/1100
# Downloaded image 0756/1100
# Downloaded image 0757/1100
# Downloaded image 0758/1100
# Downloaded image 0759/1100
# Downloaded image 0760/1100
# Downloaded image 0761/1100
# Downloaded image 0762/1100
# Downloaded image 0763/1100
# Downloaded image 0764/1100
# Downloaded image 0765/1100
# Downloaded image 0766/1100
# Downloaded image 0767/1100
# Downloaded image 0768/1100
# Downloaded image 0769/1100
# Downloaded image 0770/1100
# Downloaded image 0771/1100
# Downloaded image 0772/1100
# Downloaded image 0773/1100
# Downloaded image 0774/1100
# Downloaded image 0775/1100
# Downloaded image 0776/1100
# Downloaded image 0777/1100
# Downloaded image 0778/1100
# Downloaded image 0779/1100
# Downloaded image 0780/1100
# Downloaded image 0781/1100
# Downloaded image 0782/1100
# Downloaded image 0783/1100
# Downloaded image 0784/1100
# Downloaded image 0785/1100
# Downloaded image 0786/1100
# Downloaded image 0787/1100
# Downloaded image 0788/1100
# Downloaded image 0789/1100
# Downloaded image 0790/1100
# Downloaded image 0791/1100
# Downloaded image 0792/1100
# Downloaded image 0793/1100
# Downloaded image 0794/1100
# Downloaded image 0795/1100
# Downloaded image 0796/1100
# Downloaded image 0797/1100
# Downloaded image 0798/1100
# Downloaded image 0799/1100
# Downloaded image 0800/1100
# Downloaded image 0801/1100
# Downloaded image 0802/1100
# Downloaded image 0803/1100
# Downloaded image 0804/1100
# Downloaded image 0805/1100
# Downloaded image 0806/1100
# Downloaded image 0807/1100
# Downloaded image 0808/1100
# Downloaded image 0809/1100
# Downloaded image 0810/1100
# Downloaded image 0811/1100
# Downloaded image 0812/1100
# Downloaded image 0813/1100
# Downloaded image 0814/1100
# Downloaded image 0815/1100
# Downloaded image 0816/1100
# Downloaded image 0817/1100
# Downloaded image 0818/1100
# Downloaded image 0819/1100
# Downloaded image 0820/1100
# Downloaded image 0821/1100
# Downloaded image 0822/1100
# Downloaded image 0823/1100
# Downloaded image 0824/1100
# Downloaded image 0825/1100
# Downloaded image 0826/1100
# Downloaded image 0827/1100
# Downloaded image 0828/1100
# Downloaded image 0829/1100
# Downloaded image 0830/1100
# Downloaded image 0831/1100
# Downloaded image 0832/1100
# Downloaded image 0833/1100
# Downloaded image 0834/1100
# Downloaded image 0835/1100
# Downloaded image 0836/1100
# Downloaded image 0837/1100
# Downloaded image 0838/1100
# Downloaded image 0839/1100
# Downloaded image 0840/1100
# Downloaded image 0841/1100
# Downloaded image 0842/1100
# Downloaded image 0843/1100
# Downloaded image 0844/1100
# Downloaded image 0845/1100
# Downloaded image 0846/1100
# Downloaded image 0847/1100
# Downloaded image 0848/1100
# Downloaded image 0849/1100
# Downloaded image 0850/1100
# Downloaded image 0851/1100
# Downloaded image 0852/1100
# Downloaded image 0853/1100
# Downloaded image 0854/1100
# Downloaded image 0855/1100
# Downloaded image 0856/1100
# Downloaded image 0857/1100
# Downloaded image 0858/1100
# Downloaded image 0859/1100
# Downloaded image 0860/1100
# Downloaded image 0861/1100
# Downloaded image 0862/1100
# Downloaded image 0863/1100
# Downloaded image 0864/1100
# Downloaded image 0865/1100
# Downloaded image 0866/1100
# Downloaded image 0867/1100
# Downloaded image 0868/1100
# Downloaded image 0869/1100
# Downloaded image 0870/1100
# Downloaded image 0871/1100
# Downloaded image 0872/1100
# Downloaded image 0873/1100
# Downloaded image 0874/1100
# Downloaded image 0875/1100
# Downloaded image 0876/1100
# Downloaded image 0877/1100
# Downloaded image 0878/1100
# Downloaded image 0879/1100
# Downloaded image 0880/1100
# Downloaded image 0881/1100
# Downloaded image 0882/1100
# Downloaded image 0883/1100
# Downloaded image 0884/1100
# Downloaded image 0885/1100
# Downloaded image 0886/1100
# Downloaded image 0887/1100
# Downloaded image 0888/1100
# Downloaded image 0889/1100
# Downloaded image 0890/1100
# Downloaded image 0891/1100
# Downloaded image 0892/1100
# Downloaded image 0893/1100
# Downloaded image 0894/1100
# Downloaded image 0895/1100
# Downloaded image 0896/1100
# Downloaded image 0897/1100
# Downloaded image 0898/1100
# Downloaded image 0899/1100
# Downloaded image 0900/1100
# Downloaded image 0901/1100
# Downloaded image 0902/1100
# Downloaded image 0903/1100
# Downloaded image 0904/1100
# Downloaded image 0905/1100
# Downloaded image 0906/1100
# Downloaded image 0907/1100
# Downloaded image 0908/1100
# Downloaded image 0909/1100
# Downloaded image 0910/1100
# Downloaded image 0911/1100
# Downloaded image 0912/1100
# Downloaded image 0913/1100
# Downloaded image 0914/1100
# Downloaded image 0915/1100
# Downloaded image 0916/1100
# Downloaded image 0917/1100
# Downloaded image 0918/1100
# Downloaded image 0919/1100
# Downloaded image 0920/1100
# Downloaded image 0921/1100
# Downloaded image 0922/1100
# Downloaded image 0923/1100
# Downloaded image 0924/1100
# Downloaded image 0925/1100
# Downloaded image 0926/1100
# Downloaded image 0927/1100
# Downloaded image 0928/1100
# Downloaded image 0929/1100
# Downloaded image 0930/1100
# Downloaded image 0931/1100
# Downloaded image 0932/1100
# Downloaded image 0933/1100
# Downloaded image 0934/1100
# Downloaded image 0935/1100
# Downloaded image 0936/1100
# Downloaded image 0937/1100
# Downloaded image 0938/1100
# Downloaded image 0939/1100
# Downloaded image 0940/1100
# Downloaded image 0941/1100
# Downloaded image 0942/1100
# Downloaded image 0943/1100
# Downloaded image 0944/1100
# Downloaded image 0945/1100
# Downloaded image 0946/1100
# Downloaded image 0947/1100
# Downloaded image 0948/1100
# Downloaded image 0949/1100
# Downloaded image 0950/1100
# Downloaded image 0951/1100
# Downloaded image 0952/1100
# Downloaded image 0953/1100
# Downloaded image 0954/1100
# Downloaded image 0955/1100
# Downloaded image 0956/1100
# Downloaded image 0957/1100
# Downloaded image 0958/1100
# Downloaded image 0959/1100
# Downloaded image 0960/1100
# Downloaded image 0961/1100
# Downloaded image 0962/1100
# Downloaded image 0963/1100
# Downloaded image 0964/1100
# Downloaded image 0965/1100
# Downloaded image 0966/1100
# Downloaded image 0967/1100
# Downloaded image 0968/1100
# Downloaded image 0969/1100
# Downloaded image 0970/1100
# Downloaded image 0971/1100
# Downloaded image 0972/1100
# Downloaded image 0973/1100
# Downloaded image 0974/1100
# Downloaded image 0975/1100
# Downloaded image 0976/1100
# Downloaded image 0977/1100
# Downloaded image 0978/1100
# Downloaded image 0979/1100
# Downloaded image 0980/1100
# Downloaded image 0981/1100
# Downloaded image 0982/1100
# Downloaded image 0983/1100
# Downloaded image 0984/1100
# Downloaded image 0985/1100
# Downloaded image 0986/1100
# Downloaded image 0987/1100
# Downloaded image 0988/1100
# Downloaded image 0989/1100
# Downloaded image 0990/1100
# Downloaded image 0991/1100
# Downloaded image 0992/1100
# Downloaded image 0993/1100
# Downloaded image 0994/1100
# Downloaded image 0995/1100
# Downloaded image 0996/1100
# Downloaded image 0997/1100
# Downloaded image 0998/1100
# Downloaded image 0999/1100
# Downloaded image 1000/1100
# Downloaded image 1001/1100
# Downloaded image 1002/1100
# Downloaded image 1003/1100
# Downloaded image 1004/1100
# Downloaded image 1005/1100
# Downloaded image 1006/1100
# Downloaded image 1007/1100
# Downloaded image 1008/1100
# Downloaded image 1009/1100
# Downloaded image 1010/1100
# Downloaded image 1011/1100
# Downloaded image 1012/1100
# Downloaded image 1013/1100
# Downloaded image 1014/1100
# Downloaded image 1015/1100
# Downloaded image 1016/1100
# Downloaded image 1017/1100
# Downloaded image 1018/1100
# Downloaded image 1019/1100
# Downloaded image 1020/1100
# Downloaded image 1021/1100
# Downloaded image 1022/1100
# Downloaded image 1023/1100
# Downloaded image 1024/1100
# Downloaded image 1025/1100
# Downloaded image 1026/1100
# Downloaded image 1027/1100
# Downloaded image 1028/1100
# Downloaded image 1029/1100
# Downloaded image 1030/1100
# Downloaded image 1031/1100
# Downloaded image 1032/1100
# Downloaded image 1033/1100
# Downloaded image 1034/1100
# Downloaded image 1035/1100
# Downloaded image 1036/1100
# Downloaded image 1037/1100
# Downloaded image 1038/1100
# Downloaded image 1039/1100
# Downloaded image 1040/1100
# Downloaded image 1041/1100
# Downloaded image 1042/1100
# Downloaded image 1043/1100
# Downloaded image 1044/1100
# Downloaded image 1045/1100
# Downloaded image 1046/1100
# Downloaded image 1047/1100
# Downloaded image 1048/1100
# Downloaded image 1049/1100
# Downloaded image 1050/1100
# Downloaded image 1051/1100
# Downloaded image 1052/1100
# Downloaded image 1053/1100
# Downloaded image 1054/1100
# Downloaded image 1055/1100
# Downloaded image 1056/1100
# Downloaded image 1057/1100
# Downloaded image 1058/1100
# Downloaded image 1059/1100
# Downloaded image 1060/1100
# Downloaded image 1061/1100
# Downloaded image 1062/1100
# Downloaded image 1063/1100
# Downloaded image 1064/1100
# Downloaded image 1065/1100
# Downloaded image 1066/1100
# Downloaded image 1067/1100
# Downloaded image 1068/1100
# Downloaded image 1069/1100
# Downloaded image 1070/1100
# Downloaded image 1071/1100
# Downloaded image 1072/1100
# Downloaded image 1073/1100
# Downloaded image 1074/1100
# Downloaded image 1075/1100
# Downloaded image 1076/1100
# Downloaded image 1077/1100
# Downloaded image 1078/1100
# Downloaded image 1079/1100
# Downloaded image 1080/1100
# Downloaded image 1081/1100
# Downloaded image 1082/1100
# Downloaded image 1083/1100
# Downloaded image 1084/1100
# Downloaded image 1085/1100
# Downloaded image 1086/1100
# Downloaded image 1087/1100
# Downloaded image 1088/1100
# Downloaded image 1089/1100
# Downloaded image 1090/1100
# Downloaded image 1091/1100
# Downloaded image 1092/1100
# Downloaded image 1093/1100
# Downloaded image 1094/1100
# Downloaded image 1095/1100
# Downloaded image 1096/1100
# Downloaded image 1097/1100
# Downloaded image 1098/1100
# Downloaded image 1099/1100
# Downloaded image 1100/1100
# Saving GeoTIFF. Please wait...

# %% [markdown]
# You can also use your own image. Uncomment and run the following cell to use your own image.

# %%
# image = '/path/to/your/own/image.tif'

# %% [markdown]
# Display the downloaded image on the map.

# %%
m.layers[-1].visible = False  # turn off the basemap
m.add_raster(image, layer_name="Image")
m

# %% [markdown]
# ![](https://i.imgur.com/KAm84IY.png)

# %% [markdown]
# ## Initialize SAM class

# %%
sam = SamGeo(
    model_type="vit_h",
    checkpoint="sam_vit_h_4b8939.pth",
    sam_kwargs=None,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5ff660d3f42f> in <cell line: 0>()
# ----> 1 sam = SamGeo(
#       2     model_type="vit_h",
#       3     checkpoint="sam_vit_h_4b8939.pth",
#       4     sam_kwargs=None,
#       5 )
#
# NameError: name 'SamGeo' is not defined

# %% [markdown]
# ## Segment the image
#
# Set `batch=True` to segment the image in batches. This is useful for large images that cannot fit in memory.

# %%
mask = "segment.tif"
sam.generate(
    image, mask, batch=True, foreground=True, erosion_kernel=(3, 3), mask_multiplier=255
)

# %% [markdown]
# ## Polygonize the raster data
#
# Save the segmentation results as a GeoPackage file.

# %%
vector = "segment.gpkg"
sam.tiff_to_gpkg(mask, vector, simplify_tolerance=None)

# %% [markdown]
# You can also save the segmentation results as any vector data format supported by GeoPandas.

# %%
shapefile = "segment.shp"
sam.tiff_to_vector(mask, shapefile)

# %% [markdown]
# ## Visualize the results

# %%
style = {
    "color": "#3388ff",
    "weight": 2,
    "fillColor": "#7c4185",
    "fillOpacity": 0.5,
}
m.add_vector(vector, layer_name="Vector", style=style)
m

# %% [markdown]
# ![](https://i.imgur.com/Ysq3u7E.png)
